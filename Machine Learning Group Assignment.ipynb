# %% [markdown]
# **Machine Learning Group Assignment - Group B**

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

import pandas as pd
#opel_corsa01_LGa file_path = '../input/opel_corsa_01_LGa.csv'
opel_corsa_01LGa = 'C:\\Users\\Liam\\opel_corsa_01_LGa.csv'
# read the data and store data in DataFrame titled opel_corsa01_data
opel_corsa01_data = pd.read_csv(opel_corsa_01LGa)
# print a summary of the data in opel_corsa_01_LGa
opel_corsa01_data.describe()
# Out:
#        AltitudeVariation  VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# count        7038.000000                7038.000000          7038.000000
# mean           -0.675845                  36.428319            36.723932
# std             1.691601                  32.901312            29.366391
# min            -9.200012                   0.000000             0.000000
# 25%            -1.500000                   8.782019            16.698035
# 50%            -0.399963                  29.273399            28.312631
# 75%             0.100037                  54.043198            47.595544
# max             5.200012                 124.749725           121.330733
#
#        VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# count           7038.000000            7038.000000               7038.000000
# mean             213.004353              -0.029563                  0.143530
# std              205.717663               2.390997                  0.744697
# ...
